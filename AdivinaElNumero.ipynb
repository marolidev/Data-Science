# %%
#Módulos importados
import FuncionesTarea
import openpyxl
def stats():
    excel_document = openpyxl.load_workbook('Puntuaciones.xlsx') 
    Hoja = excel_document['Puntuaciones']
    Hoja.append([usuario, game, modo, resultado])
    for row in Hoja:
        for cell in row:
            print(cell.value + " ", end="")
        print()
  
    excel_document.save('Puntuaciones.xlsx')

# %%
while True:
    Menu= FuncionesTarea.Menu()
    opcion= FuncionesTarea.opciones(1, 4)
    if opcion==3 or opcion==4:
        break
    dif= FuncionesTarea.dificultad(1, 3)
#Solitario modo fácil
    if opcion==1 and dif == 1:
        contador=20
        print("Partida en modo fácil. Adivina el número entre 1 y 20")
        print("El número a adivinar es: ***")
        numerojugador= int(input("Introduce un número entre 1 y 20: "))
        numero = FuncionesTarea.solitario(1, 20)
        while numero != numerojugador and contador>1:
            contador=contador-1
            if numerojugador<1 or numerojugador>20:
                print("El número no está en el rango de valores, introduce un número entre 1 y 20")
                numerojugador=int(input("Introduce un nuevo número: "))
            if numero>numerojugador:
                print("El número introducido es menor que el que hay que adivinar. Tienes ", contador, "intentos")
                numerojugador= int(input("Introduce un nuevo número: "))  
            if numero<numerojugador:
                print("El número introducido es mayor que el que hay que adivinar. Tienes", contador, "intentos")
                numerojugador=int(input("Introduce un nuevo número: "))
        if contador==1:
            print("Ya no hay más intentos, has perdido. El número era el: ", numero)
            usuario=(input("Introduce tu nombre de usuario: "))
            game=("Un jugador")
            modo=("Fácil")
            resultado=("Pierde")
            print("Estadísticas hasta el momento: \n")
            stats()
            print("¿Quieres jugar de nuevo?\n")
             
        if numero==numerojugador:
            print("Has adivinado el número!!\n")
            usuario=(input("Introduce tu nombre de usuario: "))
            game=("Un jugador")
            modo=("Fácil")
            resultado=("Gana")
            print("Estadísticas hasta el momento: \n")
            stats()
            print("¿Quieres jugar de nuevo?\n")
            
#Solitario modo medio
    if opcion==1 and dif == 2:
        contador=12
        print("Partida en modo medio. Adivina el número entre 1 y 200")
        print("El número a adivinar es: ***")
        numerojugador= int(input("Introduce un número entre 1 y 200: "))
        numero = FuncionesTarea.solitario(1, 200)
        while numero != numerojugador and contador>1:
            contador=contador-1
            if numerojugador<1 or numerojugador>200:
                print("El número no está en el rango de valores, introduce un número entre 1 y 200")
                numerojugador=int(input("Introduce un nuevo número: "))
            if numero>numerojugador:
                print("El número introducido es menor que el que hay que adivinar. Tienes ", contador, "intentos")
                numerojugador= int(input("Introduce un nuevo número: "))  
            if numero<numerojugador:
                print("El número introducido es mayor que el que hay que adivinar. Tienes", contador, "intentos")
                numerojugador=int(input("Introduce un nuevo número: "))
        if contador==1:
            print("Ya no hay más intentos, has perdido. El número era el: ", numero)
            usuario=(input("Introduce tu nombre de usuario: "))
            game=("Un jugador")
            modo=("Medio")
            resultado=("Pierde")
            print("Estadísticas hasta el momento: \n")
            stats()
            print("¿Quieres jugar de nuevo?\n")
                      
        if numero==numerojugador:
            print("Has adivinado el número!!")
            usuario=(input("Introduce tu nombre de usuario: "))
            game=("Un jugador")
            modo=("Medio")
            resultado=("Gana")
            print("Estadísticas hasta el momento: \n")
            stats()
            print("¿Quieres jugar de nuevo?\n")   
              
#Solitario modo difícil
    if opcion== 1 and dif == 3:
        contador=5
        print("Partida en modo difícil. Adivina el número entre 1 y 1000")
        print("El número a adivinar es: ***")
        numerojugador= int(input("Introduce un número entre 1 y 1000: "))
        numero = FuncionesTarea.solitario(1, 1000)
        while numero != numerojugador and contador>1:
            contador=contador-1
            if numerojugador<1 or numerojugador>1000:
                print("El número no está en el rango de valores, introduce un número entre 1 y 1000")
                numerojugador=int(input("Introduce un nuevo número: "))
            if numero>numerojugador:
                print("El número introducido es menor que el que hay que adivinar. Tienes ", contador, "intentos")
                numerojugador= int(input("Introduce un nuevo número: "))  
            if numero<numerojugador:
                print("El número introducido es mayor que el que hay que adivinar. Tienes", contador, "intentos")
                numerojugador=int(input("Introduce un nuevo número: "))
        if contador==1:
            print("Ya no hay más intentos, has perdido. El número era el: ", numero)
            usuario=(input("Introduce tu nombre de usuario: "))
            game=("Un jugador")
            modo=("Difícil")
            resultado=("Pierde")
            print("Estadísticas hasta el momento: \n")
            stats()
            print("¿Quieres jugar de nuevo?\n")
                      
        if numero==numerojugador:
            print("Has adivinado el número!!")
            usuario=(input("Introduce tu nombre de usuario: "))
            game=("Un jugador")
            modo=("Difícil")
            resultado=("Gana")
            print("Estadísticas hasta el momento: \n")
            stats()
            print("¿Quieres jugar de nuevo?\n")   
                
#Dos jugadores modo fácil
    if opcion== 2 and dif== 1:
        numero1=int(input("El jugador 1 introduce un número entre 1 y 20: "))
        for i in range (1,30):
            if numero1>1 and numero1<20:
                print(i* '***********')
            while numero1<1 or numero1>20:
                print("El valor no está en el rango, introduce un número entre 1 y 20")
                numero1=int(input("Introduce un nuevo número: "))
                if numero1>1 and numero1<20:
                    break
        numero2=int(input("Introduce el número a adivinar entre 1 y 20: "))
        contador=20
        while numero1 != numero2 and contador>1:
            contador=contador-1
            print("Número incorrecto, tienes", contador, "intentos")
            if numero2<1 or numero2>20:
                print("El número no está en el rango de valores, introduce un número entre 1 y 20")
                numero2=int(input("Introduce un nuevo número: \n"))
            if numero1<numero2:
                print("El número a adivinar es menor que el introducido")
                numero2= int(input("Introduce un nuevo número: "))
            if numero1>numero2:
                print("El número a adivinar es mayor que el introducido")
                numero2= int(input("Introduce un nuevo número: "))
                
        if contador==1: 
            print("Ya no hay más intentos, has perdido. El número era el: ", numero1)
            usuario=(input("Introduce tu nombre de usuario: "))
            game=("Dos jugadores")
            modo=("Fácil")
            resultado=("Pierde")
            print("Estadísticas hasta el momento: \n")
            stats()
            print("¿Quieres jugar de nuevo?\n")
             
        if numero1==numero2:
            print("Has adivinado el número!! \n")
            usuario=(input("Introduce tu nombre de usuario: "))
            game=("Dos jugadores")
            modo=("Fácil")
            resultado=("Gana")
            print("Estadísticas hasta el momento: \n")
            stats()
            print("¿Quieres jugar de nuevo?\n")   

            
#Dos jugadores modo medio
    if opcion== 2 and dif== 2:
        numero1=int(input("El jugador 1 introduce un número: "))
        for i in range (1,30):
            if numero1>1 and numero1<200:
                print(i* '***********')
            while numero1<1 or numero1>200:
                print("El valor no está en el rango, introduce un número entre 1 y 200")
                numero1=int(input("Introduce un nuevo número: \n"))
                if numero1>1 and numero1<200:
                    break
        numero2=int(input("Introduce el número a adivinar entre 1 y 200: "))
        contador=12
        while numero1 != numero2 and contador>1:
            contador=contador-1
            print("Número incorrecto, tienes", contador, "intentos")
            if numero1<numero2:
                print("El número a adivinar es menor que el introducido")
                numero2= int(input("Introduce un nuevo número: "))
            if numero1>numero2:
                print("El número a adivinar es mayor que el introducido")
                numero2= int(input("Introduce un nuevo número: "))
        if contador==1: 
            print("Ya no hay más intentos, has perdido. El número era el: ", numero1)  
            usuario=(input("Introduce tu nombre de usuario: "))
            game=("Dos jugadores")
            modo=("Medio")
            resultado=("Pierde")
            print("Estadísticas hasta el momento: \n")
            stats()
            print("¿Quieres jugar de nuevo?\n")
             
        if numero1==numero2:
            print("Has adivinado el número")
            usuario=(input("Introduce tu nombre de usuario: "))
            game=("Dos jugadores")
            modo=("Medio")
            resultado=("Gana")
            print("Estadísticas hasta el momento: \n")
            stats()
            print("¿Quieres jugar de nuevo?\n")   
            
 #Dos jugadores modo difícil
    if opcion==2 and dif==3:
        numero1=int(input("El jugador 1 introduce un número: "))
        for i in range (1,30):
            if numero1>1 and numero1<1000:
                print(i* '***********')
            while numero1<1 or numero1>1000:
                print("El valor no está en el rango, introduce un número entre 1 y 1000")
                numero1=int(input("Introduce un nuevo número: "))
                if numero1>1 and numero1<1000:
                    break
        numero2=int(input("Introduce el número a adivinar entre 1 y 1000: "))
        contador=5
        while numero1 != numero2 and contador>1:
            contador=contador-1
            print("Número incorrecto, tienes", contador, "intentos")
            if numero1<numero2:
                print("El número a adivinar es menor que el introducido")
                numero2= int(input("Introduce un nuevo número: "))
            if numero1>numero2:
                print("El número a adivinar es mayor que el introducido")
                numero2= int(input("Introduce un nuevo número: "))
        if contador==1: 
            print("Ya no hay más intentos, has perdido. El número era el: ", numero1) 
            usuario=(input("Introduce tu nombre de usuario: "))
            game=("Dos jugadores")
            modo=("Difícil")
            resultado=("Pierde")
            print("Estadísticas hasta el momento: \n")
            stats()
            print("¿Quieres jugar de nuevo?\n")
            
        if numero1==numero2:
            print("Has adivinado el número!! \n")
            usuario=(input("Introduce tu nombre de usuario: "))
            game=("Dos jugadores")
            modo=("Difícil")
            resultado=("Gana")
            print("Estadísticas hasta el momento: \n")
            stats()
            print("¿Quieres jugar de nuevo?\n")

 #Estadísticas
if opcion==3:
    print(stats())
    FuncionesTarea.Menu()
    FuncionesTarea.opciones(1,4)
    #al marcar esta opción, solo puedes salir del juego marcando la opción 4, si marcas cualquier otra no vuelves al juego.    
 #Salir del juego
if opcion==4:
    print()
# Out:
# 1. Partida modo solitario
# 2. Partida 2 Jugadores
# 3. Estadística
# 4. Salir
#
# Introduce un valor entre 1 y 4: 1
# Has entrado en el modo solitario.
#
# Elige la dificultad:
# 1: Fácil(20 intentos)
# 2: Media(12 intentos)
# 3: Difícil(5 intentos)
#  1
# Partida en modo fácil. Adivina el número entre 1 y 20
# El número a adivinar es: ***
# Introduce un número entre 1 y 20: 15
# El número introducido es menor que el que hay que adivinar. Tienes  19 intentos
# Introduce un nuevo número: 18
# El número introducido es mayor que el que hay que adivinar. Tienes 19 intentos
# Introduce un nuevo número: 17
# Has adivinado el número!!
#
# Introduce tu nombre de usuario: meriver
# Estadísticas hasta el momento:
#
# Usuario Modo de juego Dificultad Resultado
# meriver Un jugador Fácil Gana
# ¿Quieres jugar de nuevo?
#
# 1. Partida modo solitario
# 2. Partida 2 Jugadores
# 3. Estadística
# 4. Salir
